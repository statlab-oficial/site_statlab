# %% [raw]
# ---
# title: "Laboratório de Inovação em Estatística e Ciência de Dados"
# image: logo1.png
# about:
#   id: hero-heading
#   template: trestles
#   image-shape: round
#   image-width: 10em
#   links:
#     - icon: instagram
#       text: Instagram
#       href: https://twitter.com
#     - icon: linkedin
#       text: LinkedIn
#       href: https://linkedin.com
#     - icon: github
#       text: Github
#       href: https://github.com
# ---

# %% [markdown]
# ```{css, echo = FALSE}
# .justify {
#   text-align: justify !important
# }
# ```
#
#
# ::: {#hero-heading}
#
# O StatLab pretende ser um centro multidisciplinar que não só busca avançar o conhecimento teórico em Estatística e Ciência de Dados, mas também promover sua aplicação prática através de extensões comunitárias, consultoria e pesquisa. Este projeto reforça o papel da UFC como uma instituição na vanguarda da inovação na área de Estatística e Ciência de Dados, trazendo benefícios diretos para a sociedade em diversas formas.
#
# :::callout-warning
# ## Notícias
#
# - (22.05.2024): O StatLab foi cadastrado como projeto de extensão na PROEX.
#
# :::
#
#
# :::
